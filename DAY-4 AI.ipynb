# %%
# !pip install -q sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
model= SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
Sentences = [
"I love playing football.",
"Soccer is my favourite sport.",
"The weather is very hot today.",
"Artificial intelligence is transforming the world.",
"Machine learning is a branch of AI."]

# %%
embeddings = model.encode(Sentences)

print("embeddings Shape:",embeddings.shape)
# Out:
# embeddings Shape: (5, 384)

# %%
pairs = [
    (0,1),
    (0,2),
    (3,4),
    (1,4)
]

for i, j in pairs:
  score = cosine_similarity(
    [embeddings[i]],
    [embeddings[j]]
   )[0][0]

  print(f"Sentence {i}: {Sentences[i]}")
  print(f"Sentence {j}: {Sentences[j]}")
  print(f"Similarity Score: {score:.4f}\n")
# Out:
# Sentence 0: I love playing football.
# Sentence 1: Soccer is my favourite sport.
# Similarity Score: 0.6476
#
# Sentence 0: I love playing football.
# Sentence 2: The weather is very hot today.
# Similarity Score: 0.0212
#
# Sentence 3: Artificial intelligence is transforming the world.
# Sentence 4: Machine learning is a branch of AI.
# Similarity Score: 0.6058
#
# Sentence 1: Soccer is my favourite sport.
# Sentence 4: Machine learning is a branch of AI.
# Similarity Score: 0.1537
