# %%
#take input from user

text = input("enter a sentence:")
print("original text:",text)
# Out:
# enter a sentence:Hi, I am Harsh Singh
# original text: Hi, I am Harsh Singh

# %%
# count word frequency
words=text.lower().split()

word_freq = {}
for word in words:
  word_freq[word] = word_freq.get(word,0)+1
  print("word_freq:")
  print("word_freq")
# Out:
# word_freq:
# word_freq
# word_freq:
# word_freq
# word_freq:
# word_freq
# word_freq:
# word_freq
# word_freq:
# word_freq

# %%
import string

#remove punctuation

clean_text = text.translate(str.maketrans('', '', string.punctuation))

#convert lowercase

clean_text=clean_text.lower()

#Normalize whitespace

clean_text=" ".join(clean_text.split())

print("cleaned Text:")
print("clean_text")
# Out:
# cleaned Text:
# clean_text
